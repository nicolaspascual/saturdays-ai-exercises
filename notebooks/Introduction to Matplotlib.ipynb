# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Figures and Axes

# %%
fig = plt.figure()
fig.add_subplot(2, 2, 1) # 2 rows, 2 cols, first element
fig.add_subplot(2, 2, 4) # 2 rows, 2 cols, last element

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.set_xticks([-2, -1, 0, 1, 2])
ax.set_xticklabels(['-std2', '-std1', 'mean', 'std1', 'std2'])
# Out:
# [Text(0, 0, '-std2'),
#  Text(0, 0, '-std1'),
#  Text(0, 0, 'mean'),
#  Text(0, 0, 'std1'),
#  Text(0, 0, 'std2')]

# %%
plt.scatter(
    np.random.normal(size=10), np.random.normal(size=10)
)

# %%
plt.plot(
    np.arange(-5, 6, 0.01), np.sin(np.arange(-5, 6, 0.01))
)

# %%
plt.hist(
    np.random.normal(size=100)
)
# Out:
# (array([ 3., 15., 15., 24., 17.,  6.,  6.,  7.,  5.,  2.]),
#  array([-1.8499419 , -1.39052151, -0.93110112, -0.47168073, -0.01226034,
#          0.44716004,  0.90658043,  1.36600082,  1.82542121,  2.28484159,
#          2.74426198]),
#  <a list of 10 Patch objects>)

# %%
plt.pie(
    [0.2, 0.3, 0.5]
)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9560421cf8>,
#   <matplotlib.patches.Wedge at 0x7f956042d198>,
#   <matplotlib.patches.Wedge at 0x7f956042d6a0>],
#  [Text(0.8899186877588753, 0.6465637858537406, ''),
#   Text(-0.64656382751384, 0.8899186574910392, ''),
#   Text(1.0298943251329445e-07, -1.0999999999999954, '')])

# %%
pd.Series([0.1, 0.2, 0.3, 0.5]).plot(kind='hist')
